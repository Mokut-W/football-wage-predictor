# %%
import pandas as pd
import mysql.connector
import matplotlib.pyplot as plt
import seaborn as sns

# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost", user="root", password="Exalted.143", database="fifa_db"
)

print("Connected to MySQL!")
# Out:
# Connected to MySQL!

# %%
# Query - Top 10 highest rated players
query = """
SELECT short_name, club_name, nationality_name, overall, potential, wage_eur, value_eur
FROM players
ORDER BY overall DESC
LIMIT 10
"""

top_players = pd.read_sql(query, conn)
top_players
# Out:
# C:\Users\Mokutmfon Williams\AppData\Local\Temp\ipykernel_25124\1993566819.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   top_players = pd.read_sql(query, conn)
#           short_name            club_name nationality_name  overall  \
# 0           L. Messi  Paris Saint-Germain        Argentina       93
# 1     R. Lewandowski    FC Bayern München           Poland       92
# 2  Cristiano Ronaldo    Manchester United         Portugal       91
# 3          Neymar Jr  Paris Saint-Germain           Brazil       91
# 4       K. De Bruyne      Manchester City          Belgium       91
# 5           J. Oblak   Atlético de Madrid         Slovenia       91
# 6          K. Mbappé  Paris Saint-Germain           France       91
# 7           M. Neuer    FC Bayern München          Germany       90
# 8      M. ter Stegen         FC Barcelona          Germany       90
# 9            H. Kane    Tottenham Hotspur          England       90
#
#    potential  wage_eur    value_eur
# 0         93  320000.0   78000000.0
# 1         92  270000.0  119500000.0
# 2         91  270000.0   45000000.0
# 3         91  270000.0  129000000.0
# 4         91  350000.0  125500000.0
# 5         93  130000.0  112000000.0
# 6         95  230000.0  194000000.0
# 7         90   86000.0   13500000.0
# 8         92  250000.0   99000000.0
# 9         90  240000.0  129500000.0

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12, 6))
sns.barplot(data=top_players, x="short_name", y="overall", palette="viridis")
plt.title("Top 10 Highest Rated Players in FIFA 22", fontsize=16)
plt.xlabel("Player")
plt.ylabel("Overall Rating")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Mokutmfon Williams\AppData\Local\Temp\ipykernel_25124\2020129581.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_players, x='short_name', y='overall', palette='viridis')
